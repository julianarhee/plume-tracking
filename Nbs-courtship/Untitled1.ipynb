# %%
import importlib
import sys
import os
import glob
#
import pandas as pd
import numpy as np
import matplotlib as mpl
mpl.use('nbagg')
import seaborn as sns
import pylab as pl

# import some custom funcs
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import utils as util
import behavior as butil
import auxiliary as aux
import plotting as putil

# %%
util.set_sns_style(style='dark', min_fontsize=8)
# %matplotlib notebook

# %%
rootdir = '/Volumes/Julie/2p-data'
session = '20230713' 
sessdir = os.path.join(rootdir, session)
#
neural_dir = os.path.join(sessdir, 'raw')

# %%
tif_dir = glob.glob(os.path.join(neural_dir, '*-001'))[0]
ch1 = sorted(glob.glob(os.path.join(tif_dir, '*Ch1*ome.tif')), key=util.natsort)
len(ch1)
# Out:
# 1823

# %%
import tifffile as tf

# %%
print(ch1[0])
# im1 = tf.imread(ch1[0])
# im1.shape
# Out:
# /Volumes/Julie/2p-data/20230713/raw/TSeries-07132023-1600_test-001/TSeries-07132023-1600_test-001_Cycle00001_Ch1_000001.ome.tif

# %%
#%%timeit
#6min 40s ± 2min 10s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# outfile = os.path.join(neural_dir, 'test.tif')
# with tf.TiffWriter(outfile, ome=True) as stack:
#     for filename in ch1: #glob.glob('nucleus/*.tif'):
#         #print(filename)
#         stack.write(tf.imread(filename))
# #stack.close()

# %%
os.listdir(neural_dir)
# Out:
# ['TSeries-07132023-1600_test-001_Ch2.tif',
#  'TSeries-07132023-1600_test-001.tif',
#  'TSeries-07132023-1459_test-002_Ch1.tif',
#  'TSeries-07132023-1459_test-002.tif',
#  'TSeries-07132023-1459_test-002',
#  '.DS_Store',
#  'TSeries-07132023-1459_test-002_Ch2.tif',
#  'TSeries-07132023-1600_test-001_Ch1.tif',
#  'TSeries-07132023-1600_test-001']

# %%
os.path.exists(file_to_read)
# Out:
# True

# %%
file_to_read = os.path.join(neural_dir, 'TSeries-07132023-1600_test-001_Ch2.tif')
stk = tf.imread(file_to_read)
stk.shape
# Out:
# (1823, 100, 23)

# %%
# %matplotlib notebook

# %%
fig, ax= pl.subplots()
ax.imshow(stk[0, :])
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
5468 - 3646
# Out:
# 1822

# %%
1823*2
# Out:
# 3646

# %%
5038 - 3646
# Out:
# 1392

# %%
ome_xml = tf.tiffcomment(filename)
ome = ome_types.from_xml(ome_xml)
ome.images[0].description = 'Image 0 description'
ome_xml = ome.to_xml()
#tiffcomment(filename, ome_xml)
