# %%
import os
import time
import sys
import scipy
import glob
import importlib
import _pickle as pkl
import pandas as pd
import numpy as np
import matplotlib as mpl
mpl.use('nbagg')
import seaborn as sns
import pylab as pl

from datetime import datetime

# import some custom funcs
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import utils as util
import behavior as butil

import shutil
import scipy.stats as spstats
import trajectory as traj

# %%
util.set_sns_style(style='dark', min_fontsize=12)
# %matplotlib notebook

# %%
# rootdir='/Users/julianarhee/Library/CloudStorage/GoogleDrive-edge.tracking.ru@gmail.com/My Drive/Edge_Tracking/Data'
rootdir = util.get_rootdir()
print(rootdir)
# Out:
# /Users/julianarhee/Library/CloudStorage/GoogleDrive-edge.tracking.ru@gmail.com/My Drive/Edge_Tracking/Data

# %%
# rootdir = '/mnt/minerva/plume-tracking/behavior'
rootdir = '/Volumes/Julie/plume-tracking/behavior'
experiment = 'PAM_activation'

srcdir = os.path.join(rootdir, experiment)
logdir = os.path.join(srcdir, 'logfiles')

figdir = os.path.join(srcdir, 'figures')
if not os.path.exists(figdir):
    os.makedirs(figdir)
print("Saving figures to: {}".format(figdir))

fig_id = srcdir
# Out:
# Saving figures to: /Volumes/Julie/plume-tracking/behavior/PAM_activation/figures

# %%
boutdir_palette = {'outbound': 'cyan', 'inbound': 'violet'} #'cyan'}

# %%
all_logfiles = glob.glob(os.path.join(logdir, '*PAM_activation*.log'))
len(all_logfiles)
# Out:
# 36

# %%
create_new=False
combined_datafile = os.path.join(srcdir, 'combined.pkl')
if not create_new:
    try:
        with open(combined_datafile, 'rb') as f:
            df0_all = pkl.load(f)
        print(df0_all.shape)
    except Exception as e:
        print(e)
        create_new=True
print("Create new? ", create_new)
# Out:
# [Errno 2] No such file or directory: '/Volumes/Julie/plume-tracking/behavior/PAM_activation/combined.pkl'
# Create new?  True

# %%
importlib.reload(butil)
importlib.reload(traj)
# Out:
# <module 'trajectory' from '/Users/julianarhee/Repositories/plume-tracking/trajectory.py'>

# %%
check_missing=[]
if create_new:
    d_list = []
    params = {}
    for fp in all_logfiles:
        print(fp)
        parent, fn = os.path.split(fp)
        fname = os.path.splitext(fn)[0]

        curr_figdir = os.path.join(figdir, 'trajectories')
        if not os.path.exists(curr_figdir):
            os.makedirs(curr_figdir)

        currcond = 'fed' if 'fed' in fname else 'fasted'
        df0_full, oparams = traj.load_df(fp)
        if df0_full is None:
            check_missing.append(fp)
            continue
        odor_ix = oparams['odor_ix']
        odor_bounds = oparams['odor_bounds']

        df0_full['condition'] = currcond
        params[fname] = oparams

        fig, ax = pl.subplots()
        ax = butil.plot_trajectory(df0_full, ax=ax, odor_bounds=odor_bounds, 
                             zero_odor_start=True)
        ax.set_title(fn, fontsize=8, loc='left')
        ax.set_aspect(1)

        util.label_figure(fig, '{}'.format(parent.split('/My Drive')[-1]))
        pl.savefig(os.path.join(curr_figdir, '{}.png'.format(fname)), dpi=300)
        pl.close()

        d_list.append(df0_full)
    # combine
    df0_all = pd.concat(d_list, axis=0).reset_index()
    # save
    with open(combined_datafile, 'wb') as f:
        pkl.dump(df0_all, f)
# Out:
# /Volumes/Julie/plume-tracking/behavior/PAM_activation/logfiles/20230201-115713_PAM_activation_fly1-PAM-ChR-fasted-ythresh1000_001.log
# <img src="data:image/png;base64,..." width="600">
# ...zeroing to odor start
# Subtracting: 51.70, 84.32
# /var/folders/6z/bhycp6jj4pxg1qt6h_j36h880000gn/T/ipykernel_5390/3711034078.py:33: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   pl.close()
# /Volumes/Julie/plume-tracking/behavior/PAM_activation/logfiles/20230202-111711_PAM_activation_fly1-PAM-ChR-fasted-ythresh500_001.log
# <img src="data:image/png;base64,..." width="600">
# ...zeroing to odor start
# Subtracting: -82.91, 60.66
# ...

# %%
importlib.reload(butil)
importlib.reload(traj)
# Out:
# <module 'trajectory' from '/Users/julianarhee/Repositories/plume-tracking/trajectory.py'>

# %%
fpath = fp
print(fpath)
config  = butil.load_experiment_config(fpath)
df0_full = butil.load_dataframe(fpath, remove_invalid=False)
df0_full = butil.process_df(df0_full)

config['experiment']
# Out:
# /Volumes/Julie/plume-tracking/behavior/PAM_activation/logfiles/20230202-190435_PAM_activation_fly0_001.log
# Changing 1
# {'pre_air_time': 0,
#  'max_total_airflow': 10,
#  'strip_width': 50,
#  'strip_spacing': 10000,
#  'percent_odor': 0,
#  'source_distance': 2000,
#  'reinforce': True,
#  'y_thresh': 0,
#  'led_intensity': 100,
#  'led_color': 'red',
#  'window_len': 5,
#  'pulse_period': 10.0}

# %%
odor_ix = df0_full[df0_full['instrip']].iloc[0].name

# %%
odor_bounds = butil.find_strip_borders(df0_full, entry_ix=odor_ix,
                                strip_width=50, strip_sep=1000)
# Out:
#  NO ODOR
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [44], line 1
# ----> 1 odor_bounds = butil.find_strip_borders(df0_full, entry_ix=odor_ix,
#       2                                 strip_width=50, strip_sep=1000)
#
# File ~/Repositories/plume-tracking/behavior.py:985, in find_strip_borders(df, entry_ix, strip_width, return_entry_sides, strip_sep, is_grid, get_all_borders)
#     981 if get_all_borders:
#     982     ogrid, in_odor = get_odor_grid(currdf,
#     983                         strip_width=strip_width, strip_sep=strip_sep,
#     984                         use_crossings=True, verbose=False)
# --> 985     odor_borders = list(ogrid.values())
#     986 else:
#     987     if entry_left_edge:
#
# AttributeError: 'NoneType' object has no attribute 'values'

# %%
mfc_var == ()
# Out:
# True

# %%
mfc_var = butil.get_odor_mfc(df0_full)
mfc_var
# Out:
# ()

# %%
d1 = pd.read_csv(fpath)
mfc_vars = [v for v in d1.columns if 'mfc' in v]
mfc_cols = sns.color_palette('colorblind', n_colors=len(mfc_vars))

fig, ax = pl.subplots()
for m, c in zip(mfc_vars, mfc_cols):
    sns.scatterplot(data=d1, ax=ax, x='ft_frame', y=m, c=c, edgecolor='none', s=5)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
curr_figdir = os.path.join(figdir, 'trajectories')
curr_figdir
# Out:
# '/Volumes/Julie/plume-tracking/behavior/PAM_activation/figures/trajectories'

# %%
len(df0_all['filename'].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 len(df0_all['filename'].unique())
#
# NameError: name 'df0_all' is not defined

# %%
#max_instrip_upwind_dist = 500 #250 #250
#min_sum_instrip_upwind_dist = 250
#min_global_upwind_dist = 300
max_crossovers = 2
max_instrip_upwind_percent=0.4
min_outside_bouts=5

ets=[]
for fn, df_ in df0_all.groupby('filename'):
    et_bouts, et_boutstats, et_passkey = traj.find_et_bouts(df_,
                                    odor_bounds, strip_width=50, strip_sep=1000, 
                                   max_instrip_upwind_percent=max_instrip_upwind_percent, 
                                   max_crossovers=max_crossovers, 
                                    min_outside_bouts=min_outside_bouts)
    if len(et_bouts)>0:
        ets.append(fn)
        
aggr_figname = 'traj_max-crossovers-{}_min-outside-bouts-{}_max-instrip-upwind-perc-{}_n{}'\
                .format(max_crossovers, min_outside_bouts, str(max_instrip_upwind_percent).replace('.', ''), len(ets))
print(aggr_figname)

# %%
etdf = df0_all[df0_all['filename'].isin(ets)].copy()

# %%
curr_figdir = os.path.join(figdir, 'ets', 'trajectories')
if not os.path.exists(curr_figdir):
    os.makedirs(curr_figdir)
existing_ = glob.glob(os.path.join(curr_figdir, '*.png'))
if len(existing_) > 0:
    print("Removing {} existing".format(len(existing_)))
    for f in existing_:
        os.remove(f)
        
for fp, df_ in etdf.groupby('fpath'):
    parentdir, fname = os.path.split(fp)
    fn = os.path.splitext(fname)[0]
    all_fp = os.path.join(parentdir, 'trajectories', '{}.png'.format(fn))
    dst_fp = os.path.join(curr_figdir, '{}.png'.format(fn))
    shutil.copy(all_fp, dst_fp)

# %%
curr_figdir = os.path.join(srcdir, 'ets')
nr=5
nc=7
fig, axn = pl.subplots(nr, nc, figsize=(15,8), sharex=True)
for fi, (fn, df_) in enumerate(etdf.groupby('filename')):
    if fi >= nr*nc:
        break
    ax=axn.flat[fi]
    # PLOT
    last_ = df_[df_['instrip']]['boutnum'].max()
    plotdf = df_[df_['boutnum']<=last_].copy()
    butil.plot_zeroed_trajectory(plotdf, ax=ax, traj_lw=.75, odor_lw=.5,
                                 strip_width=50, #params[fn]['strip_width'],
                                 strip_sep=1000) #params[fn]['strip_sep'])
    # legend
    ax.axis('off')
    if fi==0:
        leg_xpos=-150; leg_ypos=0; leg_scale=100
        butil.vertical_scalebar(ax, leg_xpos=leg_xpos, leg_ypos=leg_ypos)
    #ax.set_box_aspect(3)
    ax.set_xlim([-150, 150])
    ax.set_ylim([-100, 1600])
    #ax.set_title('{}\n{}'.format(fi, fn), fontsize=4, loc='left')
    ax.set_title('{}'.format(fi), fontsize=10, loc='left')

for ax in axn.flat[fi:]:
    ax.axis('off')
    ax.set_aspect(0.5)
    
pl.tight_layout()
#pl.subplots_adjust(top=0.85, hspace=0.4, wspace=0.5) #left=0.1, right=0.9, wspace=1, hspace=1, bottom=0.1, top=0.8)
util.label_figure(fig, figid)

pl.savefig(os.path.join(curr_figdir, '{}_numbered.png'.format(aggr_figname)))
print(os.path.join(curr_figdir, '{}.png'.format(aggr_figname)))

# %% [markdown]
# # bout metrics

# %%
boutdf = pd.concat([df_.groupby(['boutnum', 'condition'], group_keys=True)\
                 .apply(butil.get_bout_metrics).unstack().reset_index() \
                 for fn, df_ in etdf.groupby(['filename'])]).reset_index()
boutdf['instrip'] = boutdf['instrip'].astype(bool)

check_cols=[]
for c in boutdf.columns.tolist():
    if not pd.api.types.is_numeric_dtype(boutdf[c]):
        check_cols.append(c)
non_numeric = [
    'experiment',
    'filename',
    'fly_name',
    'fpath',
    'strip_type',
    'condition',
    'trial']
fix_cols = [c for c in check_cols if c not in non_numeric]
for c in fix_cols:
    boutdf[c] = boutdf[c].astype(float)
for c in boutdf.columns.tolist():
    if not pd.api.types.is_numeric_dtype(boutdf[c]):
        check_cols.append(c)
check_cols

boutdf.shape

# %%
# filter
d_list = []
for fn, df_ in boutdf.groupby('filename'):
    first_instrip = df_[df_['instrip']]['boutnum'].min()
    last_instrip = df_[df_['instrip']]['boutnum'].max()
    tmpdf = df_[(df_['boutnum']<=last_instrip) & (df_['boutnum']>first_instrip)]
    #print(first_instrip, last_instrip, tmpdf.shape)
    d_list.append(tmpdf)
boutdf_filt = pd.concat(d_list, axis=0).reset_index(drop=True)
print(boutdf_filt.shape)

# %%
mean_boutdf = boutdf_filt.groupby(['filename', 'instrip', 'condition']).mean().reset_index()
mean_boutdf['bout_type'] = ['instrip' if i==1 else 'outstrip' for i in mean_boutdf['instrip']]
mean_boutdf['instrip'] = mean_boutdf['instrip'].astype(bool)
mean_boutdf.shape
mean_boutdf.columns
